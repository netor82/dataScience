# %% [markdown]
# # Pruebas de Hipótesis - Lección 5 - Grabación 5
#
# Es importante resaltar que las hipótesis son afirmaciones sobre la población o distribución bajo estudio, no sobre la muestra. El valor del parámetro poblacional especificado en la hipótesis nula usualmente se determina de acuerdo a
#
# - **Experiencia previa o conocimiento del proceso**.
#   - **Objetivo**: Determinar si el valor del parámetro ha cambiado
#   - **Ejemplo**: Máquina dispensadora de café
#
# - **Teorías o modelos respecto al proceso bajo estudio**.
#   - **Objetivo**: Verificar la teoría o el modelo
#   - **Ejemplo**: Modelo climatológico sobre predicción de precipitaciones
#
# - **Consideraciones externas**: Diseño, especificaciones ingenieriles u obligaciones contractuales.
#   - **Objetivo**: Prueba de conformidad (metodología usada en ingeniería para asegurar que un producto, proceso o un programa de computadora cumple con un conjunto definido de requerimientos o estándares)
#   - **Ejemplo**: Que un modelo $X$ de automóvil consuma en promedio $\mu$ millas por galón en ciudad. Que un medicamento cure una enfermedad en el 95% de los casos. Que un algoritmo tenga una presición promedio de 0.85
#
#
# Pasos
# 1. tomar una muestra aleatoria
# 1. calcular un estadístico
# 1. usar ese estadístico para aceptar o rechazar la hipótesis nula
#
# región de aceptación (RA)
# región de rechazo (RR)
# valores críticos.
# ![](./resumen_lecc5.png)
#
#
# ## Procedimiento general de prueba de hipótesis
#
# Pasos:
#
# 1. Identificar el parámetro de interés
#
# 2. Establecer la hipótesis nula, $H_0$
#
# 3. Especificar una hipótesis alternativa apropiada, $H_1$
#
# 4. Escoger un nivel de significancia $\alpha$
#
# 5. Determinar el estadístico apropiado para la prueba:
#
# $$Z = \frac{\overline{x}-\mu_{\overline{x}}}{\sigma_\overline{x}} = \frac{\textrm{estimador del param}-\textrm{valor del param dado por H_0}}{\textrm{error estándar del estimador}}$$
#
# > otra opción es
#
# $$
# t = \frac{\overline{x} - \mu_0}{S / \sqrt{n}}
# $$
# con $S$ es la desviación estándar muestral, que aproxima a $\sigma$ conforme $n \rightarrow\infty$, no a $\sigma_\overline{x}$ que es la desviación estándar de las medias muestrales.
#
# 6. Establecer la región de rechazo para el estadístico ($\alpha$ o $\alpha$/2)
#
# 7. Cálcular el estadístico de la prueba, el Z o el T
#
# 8. Decidir si $H_0$ debe ser rechazada y reportar el resultado bajo el contexto del problema.  Ejemplo
#
# Conclusión: Dado que 𝑧=3.25>1.96, se rechaza $𝐻_0:\mu=50$ con un nivel de significancia de 0.05. Dicho en otras palabras, concluimos que la tasa de combustión media difiere de 50 centímetros por segundo basados en una muestra de 25 observaciones.
#
# **Importante**: los pasos del 1 al 4 deberían de ser completados antes de examinar los datos muestrales.

# %% [markdown]
# ## Error Tipo I:  $H_0$ es cierta, yo la rechazo: falso positivo
#
#
# Nivel de significancia, nivel de la prueba, o $error- \alpha$:
#
# \begin{equation}
# \alpha=Pr\left(\textrm{Error Tipo I}\right)=Pr(\textrm{rechazar } H_0 \textrm{ cuando } H_0 \textrm{es verdadera}).
# \end{equation}
#
# ### Reducción de $\alpha$
# - ampliando la región de aceptación (RA)
# - incrementando el tamaño de la muestra
#
#
# ## Error Tipo II: $H_0$ es falsa, yo la acepto: falso negativo
#
# Para calcular $\beta$ se debe tener un **valor específico de $\mu$** para la hipótesis alternativa.
#
# La probabilidad de cometer un error tipo II incrementa rápidamente en cuanto el valor específico de 𝜇 para la hipótesis alternativa se aproxima a la región de aceptación.
#
# 1−𝛽, se le conoce como la **potencia de una prueba estadística** y se interpreta como la probabilidad de correctamente rechazar una hipótesis nula cuando esta es falsa
#
#
# ## Conclusiones sobre $\alpha$ y $\beta$
#
# 1. El área bajo la curva de la región de rechazo va a ser igual a  la probabilidad de un error de tipo I $\alpha$
#
# 2. Si mantenemos el tamaño de muestra constante, una disminución en la probabilidad del error de tipo I implica un aumento en la probabilidad del error tipo II y viceversa.
#
# 3. Un incremento en el tamaño de muestra reduce tanto $\alpha$ como $\beta$, si se mantienen constantes los valores críticos.
#
# 4. Para el cálculo de $\beta$, entre más cercano sea el valor específico escogido para la hipótesis alternativa respecto al valor dado por la hipótesis nula, más grande será el valor de $\beta$.
#
#
# ## Impacto del tamaño de muestra en el margen de error
# \begin{equation}
# \overline{x}\pm \rho=\overline{x}\pm\frac{\sigma\, z_{\alpha/2}}{\sqrt{n}},
# \end{equation}
#
# podemos replantear los requerimientos muestrales como:
#
# \begin{equation}
# n = \left(\dfrac{\sigma z_{\alpha/2}}{\rho} \right)^2
# \end{equation}
#
#
# # ANOVA Análisis of Variance - Lecc6
#
# Análisis de resultados experimentales. El ANOVA particiona la variabilidad total.
# ![](https://drive.google.com/uc?export=view&id=1dKlHBYXf9sJ-BmO_Yyi4zcpohb8c9SGR)
#
# tómese $\textrm{MS}_E=\textrm{MS}_\textrm{error}$.
